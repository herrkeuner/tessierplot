# %%
import imp
from tessierplot import view
imp.reload(view)

#view.tessierView(rootdir='C:/Users/mbrauns/OneDrive/Dokumente/Postdoc IST/Ge hut wires/Mobility_for_Hannes',filterstring='',override=True, showfilenames=True)
view.tessierView(rootdir='C:/Users/mbrauns/OneDrive/Dokumente/Software development/testdata/qtlab',filterstring='',override=True, showfilenames=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# C:/Users/mbrauns/OneDrive/DOKUME~1/SOFTWA~1/testdata/qtlab\20180421\200557~2/200557_I_V_vs_Bforconstantangle_11-13-12.dat
# xu: 1201, yu: 67, lenz: 80467
# xu: 1201, yu: 67, lenz: 80467 after trimming
# C:\Users\mbrauns\conda\envs\conda3_qt5\lib\site-packages\numpy\core\fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# C:\Users\mbrauns\conda\envs\conda3_qt5\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: The mpl_toolkits.axes_grid module was deprecated in version 2.1. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist provies the same functionality instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ...

# %%
import os
import json
filename= '../../testdata/qcodes/2018-0~1/#046_2~1/IVVI_dac3_attenuated_set_IVVI_dac1_attenuated_set.dat'
json_file = ''.join((os.path.dirname(filename),'/snapshot.json'))
#print(filename)
print(json_file)
filebuffer = open(json_file)
json_s=filebuffer.read()

json_data = json.loads(json_s)
headerdict = json_data['arrays']
header=[]
headerlength=0

for i,val in enumerate(headerdict):
    if headerdict[val]['is_setpoint']:
        line=[i,headerdict[val]['name'],'coordinate']
        line_x = zip(['column','name','type'],line)
        header.append(line_x)
        headerlength=headerlength+1
    else:
        line=[i,headerdict[val]['name'],'value']
        line_x = zip(['column','name','type'],line)
        header.append(line_x)
        headerlength=headerlength+1

header = [dict(x) for x in header]
print(header)
print(headerlength)
        #pass#print(headerdict[val]['name'])

# %%
print(json_data['arrays'])

# %%
print(os.path.dirname(file))
