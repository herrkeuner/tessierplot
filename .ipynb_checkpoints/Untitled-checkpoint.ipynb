# %%
import imp
from tessierplot import view
imp.reload(view)

view.tessierView(rootdir='../../testdata/qcodes',filterstring='',override=False, showfilenames=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ../../testdata/qcodes\2018-0~1\#046_2~1/IVVI_dac3_attenuated_set_IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#046_2~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#046_2~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#046_2~1/IVVI_dac3_attenuated_set_IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#045_1~1/IVVI_dac3_attenuated_set_IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#045_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#045_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#045_1~1/IVVI_dac3_attenuated_set_IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#044_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#044_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#044_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#044_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#043_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#043_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#043_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#043_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#042_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#042_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#042_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#042_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#041_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#041_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#041_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#041_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#040_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#040_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#040_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#040_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#039_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#039_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#039_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#039_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#038_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#038_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#038_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#038_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#037_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#037_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#037_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#037_1~1/IVVI_dac3_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#036_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#036_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#036_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#036_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#035_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#035_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#035_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#035_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#034_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#034_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#034_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#034_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#033_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#033_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#033_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#033_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#032_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#032_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#032_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#032_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#031_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#031_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#031_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#031_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#030_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#030_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#030_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#030_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#029_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#029_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#029_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#029_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#028_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#028_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#028_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#028_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#027_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#027_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#027_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#027_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#026_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#026_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#026_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#026_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#025_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#025_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#025_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#025_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#024_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#024_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#024_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#024_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#023_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#023_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#023_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#023_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#022_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#022_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#022_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#022_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#021_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#021_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#021_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#021_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#020_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#020_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#020_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#020_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#019_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#019_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#019_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#019_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#018_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#018_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#018_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#018_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#017_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#017_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#017_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#017_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#016_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#016_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#016_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#016_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#015_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#015_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#015_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#015_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#014_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#014_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#014_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#014_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#013_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#013_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#013_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#013_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#012_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#012_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#012_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#012_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#011_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#011_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#011_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#011_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#010_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#010_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#010_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#010_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#009_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#009_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#009_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#009_1~1/IVVI_dac2_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#008_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#008_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#008_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#008_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#007_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#007_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#007_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#007_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#006_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#006_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#006_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#006_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#005_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#005_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#005_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#005_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#004_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#004_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#004_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#004_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#003_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#003_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#003_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#003_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#002_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#002_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#002_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#002_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#001_1~1/IVVI_dac1_attenuated_set.dat
# ../../testdata/qcodes\2018-0~1\#001_1~1/snapshot.json
# ../../testdata/qcodes\2018-0~1\#001_1~1/snapshot.json
# Error super(type, obj): obj must be an instance or subtype of type for file ../../testdata/qcodes\2018-0~1\#001_1~1/IVVI_dac1_attenuated_set.dat
#
#         <meta http-equiv="Cache-Control" content="no-cache, no-store, must-revalidate">
#         <meta http-equiv="Pragma" content="no-cache">
#         <meta http-equiv="Expires" content="0">
#
#         <div id='outer'>
#
#
#
#
#
#     </div>
#
#
#         <script type="text/Javascript">
#             var py_callbacks =[];
#             function handle_output(out){
#                 // done executing python output now filter on which event
#                 if (out.msg_type == "execute_result") {
#                     for (var key in py_callbacks) {
#                         key = py_callbacks[key]
#                         if (out.parent_header.msg_id == key.msg_id) {
#                             //call the callback with arguments
#                             key.cb(key.cb_args);
#                             //and remove from the list
#                             py_callbacks.pop(key);
#                         }
#                     }
#                 }
#             }
#             function pycommand(exec,cb,cb_args){
#                 exec = exec.replace(/\\/g,"\\\\");
#                 var kernel = IPython.notebook.kernel;
#                 var callbacks = { 'iopub' : {'output' : handle_output}};
#                 var msg_id = kernel.execute(exec, callbacks, {silent:false});
#
#                 if (cb != undefined) {
#                     py_callbacks.push({msg_id: msg_id, cb: cb, cb_args: cb_args});
#                 }
#             }
#             function jump(h){
#                 var url = location.href;               //Save down the URL without hash.
#                 location.href = "#"+h;                 //Go to the target element.
#                 history.replaceState(null,null,url);   //Don't like hashes. Changing it back.
#             }
#             function tovar(id) {
#                 exec =' filename \= "' + id + '"';
#                 pycommand(exec);
#             }
#             function toclipboard(id) {
#                 exec ='import pyperclip; pyperclip.copy("' + id + '");pyperclip.paste()';
#                 pycommand(exec);
#             }
#             function refresh(id) {
#                 id = id.replace(/\\/g,"\\\\");
#
#                 exec ='from tessierplot import view;  a=view.tessierView();a.makethumbnail("' + id + '",override=True)';
#                 pycommand(exec,refresh_callback,id);
#
#             }
#             function refresh_callback(id) {
#                 var x = document.querySelectorAll('div[id=\"'+id+'\"]')[0];
#                 var img = x.getElementsByTagName('img')[0];
#                 img.src = img.src.split('?')[0] + '?' + new Date().getTime();
#             }
#             function getStyle(id) {
#                 id = id.replace(/\\/g,"\\\\");
#                 var x = document.querySelectorAll('form[name=\"'+id+'\"]')
#                 form = x[0]; //should be only one form
#                 selector = form.selector;
#                 var stylevalues = selector.options[selector.selectedIndex].value
#                 if(form.stylechecker.checked) {
#                     stylevalues = form.stylechecker.value + stylevalues
#                 }
#                 var style = "[" + stylevalues + "]";
#                 return style
#             }
#             function plotwithStyle(id) {
#                 var style = getStyle(id);
#                 plot(id,style);
#             }
#
#             function plot(id,x,y){
#                 dir = id.split('/');
#
#                 exec = 'filename \= "' + id + '"; \nimport matplotlib.pyplot as plt\nimport imp\nif not plt.get_fignums():\n from tessierplot import plot as ts\n imp.reload(ts)\np = ts.plotR(filename)\np.quickplot(style= %s)\n';
#                 exec = exec.printf(x)
#
#                 pycommand(exec);
#             }
#             String.prototype.printf = function (obj) {
#                 var useArguments = false;
#                 var _arguments = arguments;
#                 var i = -1;
#                 if (typeof _arguments[0] == "string") {
#                 useArguments = true;
#                 }
#                 if (obj instanceof Array || useArguments) {
#                 return this.replace(/\%s/g,
#                 function (a, b) {
#                   i++;
#                   if (useArguments) {
#                     if (typeof _arguments[i] == 'string') {
#                       return _arguments[i];
#                     }
#                     else {
#                       throw new Error("Arguments element is an invalid type");
#                     }
#                   }
#                   return obj[i];
#                 });
#                 }
#                 else {
#                 return this.replace(/{([^{}]*)}/g,
#                 function (a, b) {
#                   var r = obj[b];
#                   return typeof r === 'string' || typeof r === 'number' ? r : a;
#                 });
#                 }
#             };
#
#         </script>
#
#         <style type="text/css">
# /*         .container { width:100% !important; } */
#         @media (min-width: 30em) {
#             .row {  width: auto;
#                     display: table;
#                     table-layout: fixed;
#                     padding-top: 1em;
#                     }
#             .col { display: table-cell;
#                     padding-right: 1em;
#                     position:relative;
#                     }
#         }
#         .col .name { z-index:5;
#                     font-size: 10pt;
#                     color:black;
#                     position:absolute;
#                     top: 2px;
#                     width:80% ;
#                     border: solid black 1px;
#                     background-color: white;
#                     word-break:break-all;
#                     opacity:0;
#                     -moz-transition: all .2s;
#                     -webkit-transition: all .2s;
#                     transition: all .2s;
#                     }
#         .col:hover .name {
#                     opacity:1;
#                 }
#
#         .datesep { width:100%;
#                    height: auto;
#                    border-bottom: 2pt solid black;
#                    font-size:14pt;
#                    font-weight:bold;
#                    font-style: italic;
#                    padding-top: 2em;}
#         #outer {}
#         img{
#             width:100%;
#             height:auto;
#             }
#         </style>

# %%
import os
import json
filename= '../../testdata/qcodes/2018-0~1/#046_2~1/IVVI_dac3_attenuated_set_IVVI_dac1_attenuated_set.dat'
json_file = ''.join((os.path.dirname(filename),'/snapshot.json'))
#print(filename)
print(json_file)
filebuffer = open(json_file)
json_s=filebuffer.read()

json_data = json.loads(json_s)
headerdict = json_data['arrays']
header=[]
headerlength=0

for i,val in enumerate(headerdict):
    if headerdict[val]['is_setpoint']:
        line=[i,headerdict[val]['name'],'coordinate']
        line_x = zip(['column','name','type'],line)
        header.append(line_x)
        headerlength=headerlength+1
    else:
        line=[i,headerdict[val]['name'],'value']
        line_x = zip(['column','name','type'],line)
        header.append(line_x)
        headerlength=headerlength+1

header = [dict(x) for x in header]
print(header)
print(headerlength)
        #pass#print(headerdict[val]['name'])

# %%
print(json_data['arrays'])

# %%
print(os.path.dirname(file))
